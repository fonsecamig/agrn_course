# %% [markdown]
# # Transformer Decoder

# %% [markdown]
# ## 1
# Consider the dataset relative to daily data on the S&P 500, NASDAQ Composite, Dow Jones Industrial Average, FTSE 100, Nikkei 225, Hang Seng Index, Swiss Market Index, DAX Index, CAC 40 and Euro Stoxx 50, from 2015-1-1 to 2025-12-31. Train a model to generate index close values for the following 730 days.
