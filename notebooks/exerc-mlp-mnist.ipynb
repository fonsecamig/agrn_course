# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # TensorFlow 2 — MNIST Exercise
#
# In this exercise you will:
#
# 1. Load the MNIST dataset
# 2. Preprocess image data
# 3. Build a neural network classifier
# 4. Train and evaluate the model
# 5. Visualize predictions
#
# Goal: build your **first image classifier with TensorFlow**.

# %% [markdown]
# ## Step 1 — Load the MNIST Dataset
#
# MNIST contains **70,000 handwritten digits (0–9)**.
#
# - 60,000 training images
# - 10,000 test images
# - image size: **28 × 28 pixels**

# %%
mnist = tf.keras.datasets.mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

print(X_train.shape)
print(X_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# ## Step 2 — Visualize Some Digits

# %%
plt.figure(figsize=(6,6))

for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[i], cmap="gray")
    plt.title(y_train[i])
    plt.axis("off")

plt.show()

# %% [markdown]
# ## Step 3 — Normalize Pixel Values
#
# Neural networks train better if inputs are scaled.

# %%
# TODO
X_train = None
X_test = None

# %% [markdown]
# ## Step 4 — Build the Neural Network
#
# Create a network with:
#
# - Flatten layer
# - Dense hidden layer (128 neurons, ReLU)
# - Output layer (10 neurons, softmax)

# %% [markdown]
# ## Step 5 — Compile the Model
#
# Use:
#
# - optimizer = Adam
# - loss = sparse categorical cross-entropy
# - metric = accuracy

# %% [markdown]
# ## Step 6 — Train the Model
#
# Train the model for 5 epochs using a training batch size of 32, with a training/validation split of 80%/20%.

# %%
# TODO

history = model.fit(
    None,
    None,
    epochs=None,
    validation_split=None
)

# %% [markdown]
# ## Step 7 — Plot Accuracy

# %%
# TODO

plt.plot(None, label="train")
plt.plot(None, label="validation")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 8 — Evaluate on Test Data

# %%
# TODO

model.evaluate(None, None)

# %% [markdown]
# ## Step 9 — Predictions
#
# Predict the class of 5 test images.

# %% [markdown]
# ## Step 10 — Visualize Predictions
#
# Visualize the predicted class and the true label for each image.

# %% [markdown]
# ## Extra Step — Improve the Model
#
# Try to:
#
# - Increase hidden neurons to 256
# -  Add another hidden layer
# - Train for 10 epochs
#
# *Example architecture: Flatten → Dense(256) → Dropout → Dense(10)*
