# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# # Data

# %%
X, y = make_classification(n_samples=600, n_features=30, n_classes=2, n_informative=10)

# %% [markdown]
# . `X`: feature matrix of shape `(n_samples, n_features)`
# . `y`: target vector of shape `(n_samples,)`

# %% [markdown]
# # Questions

# %% [markdown]
# ## 1.

# %% [markdown]
# ### 1.1
# Split the data into training, validation, and test sets with a 70%/15%/15% split.

# %% [markdown]
# :::{.callout-tip}
# Use the `train_test_split` function from `sklearn.model_selection`.
# :::

# %% [markdown]
# ### 1.2
# Fit a logistic regression model to the training data using all features and evaluate its performance on the validation set using accuracy and obtaining the confusion matrix.

# %% [markdown]
# :::{.callout-tip}
# Use `LinearRegression` from `sklearn.linear_model` and `mean_squared_error` and `r2_score` from `sklearn.metrics`.
# :::

# %% [markdown]
# ### 1.3
# Fit a logistic regression model to the training data using the first 10 features and evaluate its performance on the validation set using accuracy and obtaining the confusion matrix. Compare the results to the model trained on all features.

# %% [markdown]
# ## 2.
# Repeat the steps in question 1, but this time use 5-fold cross-validation instead of a single train/validation/test split. Report the average MSE and $R^2$ across the 5 folds for both models (all features vs. first 10 features). Compare the results to the single train/validation/test split approach.
