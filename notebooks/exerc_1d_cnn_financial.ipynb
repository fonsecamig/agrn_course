# %% [markdown]
# # 1D CNN Exercise with Financial Data
#
# Build a **1D Convolutional Neural Network (Conv1D)** in **TensorFlow 2** to predict whether the **next-day return** of a financial asset will be **positive or negative**.

# %% [markdown]
# ## Prediction task
#
# At each time step $t$, use the previous **20 daily returns** to predict:
#
# $$
# y_{t + 1} = \begin{cases}
# 1 & \text{if } r_{t+1} > 0 \\
# 0 & \text{if } r_{t+1} \le 0
# \end{cases}
# $$
#
# We will use **SPY** (S&P 500 ETF) from Yahoo Finance.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers, models
from sklearn.metrics import classification_report, confusion_matrix

import yfinance as yf

print('TensorFlow version:', tf.__version__)
# Out:
# TensorFlow version: 2.20.0

# %% [markdown]
# ## 1. Download financial data

# %%
ticker = 'SPY'
df = yf.download(ticker, start='2015-01-01', end='2025-01-01')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open     Volume
# Ticker             SPY         SPY         SPY         SPY        SPY
# Date
# 2015-01-02  170.124954  171.325768  169.089778  170.911698  121465900
# 2015-01-05  167.052551  169.247119  166.746143  169.081494  169632600
# 2015-01-06  165.479141  167.880745  164.684120  167.359012  209151400
# 2015-01-07  167.541199  167.880740  166.356963  166.804154  125346700
# 2015-01-08  170.514267  170.729592  168.932527  168.949081  147217800

# %% [markdown]
# ## 2.
# Compute daily returns

# %% [markdown]
# ## 3.
# Visualize the time series

# %% [markdown]
# ## 4.
# Create rolling windows
#
# - use the last **20 returns** as input features.

# %% [markdown]
# ## 5.
# Add a channel dimension
#
# - TensorFlow Conv1D expects input shape: `(samples, timesteps, channels)`
# - Since we have only one feature (returns), we need to add a channel dimension.
# - Use `np.expand_dims`, `np.newaxis` or `reshape` to add a channel dimension to the input data.

# %% [markdown]
# ## 6.
# Train/test split
#
# - Use a time-based split to avoid data leakage.

# %% [markdown]
# ## 7.
# Build the 1D CNN with architecture:
# - Conv1D layer with 32 filters, kernel size of 3, and ReLU activation.
# - MaxPooling1D layer with pool size of 2.
# - Conv1D layer with 64 filters, kernel size of 3, and ReLU activation.
# - MaxPooling1D layer with pool size of 2.
# - GlobalAveragePooling1D layer to reduce the output to a single vector.
# - Dense output layer with 1 unit and sigmoid activation for binary classification.

# %% [markdown]
# ## 8.
# Compile the model, choosing appropriate loss function, optimizer, and evaluation metrics.

# %% [markdown]
# ## 9.
# Train the model for 20 epochs with a batch size of 32.

# %% [markdown]
# ## 10.
# Plot the training history.

# %% [markdown]
# ## 11.
# Evaluate the model on test data.

# %% [markdown]
# ## 12.
#
# Try the following modifications:
#
# - change `kernel_size=3` to `kernel_size=5`
# - increase `window_size` from 20 to 60
# - add `Dropout(0.3)` before the final layer
# - compare `GlobalAveragePooling1D()` with `Flatten()`
# - replace SPY with `QQQ` or `^GSPC`

# %% [markdown]
# # Extra — Multi-feature 1D CNN
#
# Add to the model more realistic financial features:
#
# - return
# - rolling volatility
# - moving average ratio
# - volume change
