# %%
import numpy as np
import matplotlib.pyplot as plt
import optuna
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ## MNIST Data

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %% [markdown]
# ## Baseline Model
#
# Train a baseline model on the MNIST dataset using a simple feedforward neural network with one hidden layer with 16 neurons. Use the following hyperparameters:
# - Number of epochs: 1000
# - Batch size: 4
# - Learning rate: 0.01
#
# Use the ReLU activation function for the hidden layer and the softmax activation function for the output layer. Report the training and validation accuracy after training the model.

# %% [markdown]
# ## Tuning Hyperparameters
# Optimize:
# - learning rate
# - number of layers
# - units per layer
# - dropout
